# %%
import pandas as pd

# For GBD Regions
df = pd.read_csv("/Users/emilypalm/Library/Mobile Documents/com~apple~CloudDocs/Documents/GitHub/capstone-3/Machine_Learning/IHME-GBD_2021_DATA-d09f194b-1/GBD_regions.csv")

# For Super Regions 
df_super = pd.read_csv("/Users/emilypalm/Library/Mobile Documents/com~apple~CloudDocs/Documents/GitHub/capstone-3/Machine_Learning/IHME-GBD_2021_DATA-a6833097-1/GBD_super_regions.csv")

# Preview data
df.head(5)
# Out:
#    measure_id measure_name  location_id             location_name  sex_id  \
# 0           1       Deaths        44559                    Africa       3
# 1           1       Deaths        44560                   America       3
# 2           1       Deaths        44560                   America       3
# 3           1       Deaths        44560                   America       3
# 4           1       Deaths          239  East Asia & Pacific - WB       3
#
#   sex_name  age_id          age_name  cause_id                    cause_name  \
# 0     Both      27  Age-standardized      1029                 Total cancers
# 1     Both      27  Age-standardized       294                    All causes
# 2     Both      27  Age-standardized       302            Diarrheal diseases
# 3     Both      27  Age-standardized       322  Lower respiratory infections
# 4     Both      27  Age-standardized       294                    All causes
#
# ...

# %%
#preview data for super regions
df_super.head(5)
# Out:
#    measure_id measure_name  location_id  \
# 0           1       Deaths            4
# 1           1       Deaths            4
# 2           1       Deaths            4
# 3           1       Deaths            4
# 4           1       Deaths          166
#
#                             location_name  sex_id sex_name  age_id  \
# 0  Southeast Asia, East Asia, and Oceania       3     Both      27
# 1  Southeast Asia, East Asia, and Oceania       3     Both      27
# 2  Southeast Asia, East Asia, and Oceania       3     Both      27
# 3  Southeast Asia, East Asia, and Oceania       3     Both      27
# 4                      Sub-Saharan Africa       3     Both      27
#
#            age_name  cause_id                    cause_name  metric_id  \
# 0  Age-standardized       302            Diarrheal diseases          3
# 1  Age-standardized       294                    All causes          3
# 2  Age-standardized       322  Lower respiratory infections          3
# ...

# %%
#check all available super regions
df_super['location_name'].unique()
# Out:
# array(['Southeast Asia, East Asia, and Oceania', 'Sub-Saharan Africa',
#        'Latin America and Caribbean', 'North Africa and Middle East',
#        'World Bank Regions', 'WHO region', 'High-income',
#        'Central Europe, Eastern Europe, and Central Asia',
#        'High-middle SDI', 'South Asia', 'European Union', 'African Union',
#        'High SDI', 'Four World Regions', 'Health System Grouping Levels',
#        'League of Arab States', 'Commonwealth',
#        'Organization of Islamic Cooperation', 'Low-middle SDI',
#        'OECD Countries', 'Low SDI', 'Middle SDI', 'Nordic Region', 'G20',
#        'Association of Southeast Asian Nations',
#        'Gulf Cooperation Council', 'Sahel Region'], dtype=object)

# %%
#number of rows per region
df_super['location_name'].value_counts()
# Out:
# location_name
# Southeast Asia, East Asia, and Oceania              210
# Health System Grouping Levels                       210
# Gulf Cooperation Council                            210
# Association of Southeast Asian Nations              210
# G20                                                 210
# Nordic Region                                       210
# Middle SDI                                          210
# Low SDI                                             210
# OECD Countries                                      210
# Low-middle SDI                                      210
# Organization of Islamic Cooperation                 210
# Commonwealth                                        210
# League of Arab States                               210
# Four World Regions                                  210
# Sub-Saharan Africa                                  210
# High SDI                                            210
# ...

# %%
# Check for missing values in each column
missing_values = df_super.isnull().sum()
print("Missing values per column:\n", missing_values)
# Out:
# Missing values per column:
#  measure_id       0
# measure_name     0
# location_id      0
# location_name    0
# sex_id           0
# sex_name         0
# age_id           0
# age_name         0
# cause_id         0
# cause_name       0
# metric_id        0
# metric_name      0
# year             0
# val              0
# upper            0
# lower            0
# dtype: int64

# %%
# Sort the dataset by year to ensure chronological order
df_super = df_super.sort_values(by='year')

# %%
# Remove any duplicated rows if they exist
duplicates = df_super.duplicated().sum()
print(f"Number of duplicated rows: {duplicates}")

df_super = df_super.drop_duplicates()
# Out:
# Number of duplicated rows: 0

# %%
#Run to install prophet

# !pip install prophet

# %%
# Prophet model for forecasting
from prophet import Prophet 
# For plotting         
import matplotlib.pyplot as plt

# %%
# Filter to only death rate (rate per 100k) from diarrheal diseases
# Conditional filtering
#https://www.who.int/news-room/fact-sheets/detail/diarrhoeal-disease#:~:text=or%20severe%20dehydration).
# -,Causes,for%20drinking%2C%20cooking%20and%20cleaning. → Use diarrheal diseases as main cause in Sub-Saharan Africa

# Global aggregation: average death rate from diarrheal diseases across all countries
ts_data = df_super[
    (df_super['cause_name'] == 'Diarrheal diseases') &
    (df_super['measure_name'] == 'Deaths') &
    (df_super['metric_name'] == 'Rate')
].groupby('year')['val'].mean().reset_index()


# Preview it
ts_data.head()
# Out:
#    year        val
# 0  1980  99.817349
# 1  1981  97.412893
# 2  1982  95.157822
# 3  1983  92.948201
# 4  1984  90.550294

# %%
#Format data for prophet so... prophet expectations:
# ds: datetime column
# y: the numeric value that's going to be forecasted

# Rename columns to match Prophet's expected format
ts_data = ts_data.rename(columns={'year': 'ds', 'val': 'y'})

# Convert 'ds' to datetime 
ts_data['ds'] = pd.to_datetime(ts_data['ds'], format='%Y')

# Preview cleaned time series
ts_data.head()
# Out:
#           ds          y
# 0 1980-01-01  99.817349
# 1 1981-01-01  97.412893
# 2 1982-01-01  95.157822
# 3 1983-01-01  92.948201
# 4 1984-01-01  90.550294

# %%
# Fit the prophet model 
# Initialize the Prophet model
model = Prophet()

# Fit the model to the historical data
model.fit(ts_data)
# Out:
# 16:48:10 - cmdstanpy - INFO - Chain [1] start processing
# 16:48:11 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Create a future dataframe with 10 more years
future = model.make_future_dataframe(periods=10, freq='Y')

# Preview future dates
future.tail()
# Out:
# /opt/miniconda3/envs/SP/lib/python3.11/site-packages/prophet/forecaster.py:1854: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   dates = pd.date_range(
#            ds
# 47 2026-12-31
# 48 2027-12-31
# 49 2028-12-31
# 50 2029-12-31
# 51 2030-12-31

# %%
# Generate forecast
forecast = model.predict(future)

# Show some of the forecasted data
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(10)
# Out:
#            ds       yhat  yhat_lower  yhat_upper
# 42 2021-12-31  17.066797   16.801473   17.334055
# 43 2022-12-31  15.612212   15.239119   15.941033
# 44 2023-12-31  14.134019   13.640600   14.591363
# 45 2024-12-31  12.997705   12.253456   13.695163
# 46 2025-12-31  11.565343   10.525975   12.439367
# 47 2026-12-31  10.110758    8.785703   11.377340
# 48 2027-12-31   8.632565    6.927531   10.159851
# 49 2028-12-31   7.496251    5.364744    9.386884
# 50 2029-12-31   6.063888    3.522214    8.304772
# 51 2030-12-31   4.609304    1.609002    7.176353

# %%
# Basic Prophet forecast plot
fig = model.plot(forecast)
plt.title("Global Forecasted Death Rate from Diarrheal Diseases")
plt.xlabel("Year")
plt.ylabel("Deaths per 100,000 people")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Improved Prophet forecast plot
fig = model.plot(forecast)

# vertical line where forecast starts
forecast_start = model.history['ds'].max()
plt.axvline(x=forecast_start, color='gray', linestyle='--', label='Forecast Start')

# confidence interval shading
plt.fill_between(forecast['ds'], forecast['yhat_lower'], forecast['yhat_upper'],
                 color='skyblue', alpha=0.3, label='Confidence Interval')

# Title and labels 
plt.title("Global Forecasted Death Rate from Diarrheal Diseases\n(Deaths per 100,000 People)", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Deaths per 100,000 People", fontsize=12)

# Grid
plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)
plt.xticks(rotation=45)

# Add legend
plt.legend()

# Layout and display
plt.tight_layout()
plt.show()

# %%
# base Prophet plot
fig, ax1 = plt.subplots(figsize=(14, 6))

# Plot forecast mean line
ax1.plot(forecast['ds'], forecast['yhat'], color='navy', label='Forecasted Death Rate')

# confidence interval
ax1.fill_between(forecast['ds'], forecast['yhat_lower'], forecast['yhat_upper'],
                 color='lightblue', alpha=0.4)

# Add historical data 
ax1.scatter(model.history['ds'], model.history['y'], color='black', s=10, label='Observed Data')

# Vertical line: forecast start
forecast_start = model.history['ds'].max()
ax1.axvline(x=forecast_start, color='red', linestyle='--', linewidth=2, label='Forecast Start')

# Set labels and grid
ax1.set_title("Forecast: Global Death Rate from Diarrheal Diseases (per 100,000)", fontsize=16)
ax1.set_xlabel("Year", fontsize=12)
ax1.set_ylabel("Death Rate (per 100,000 people)", fontsize=12, color='navy')
ax1.tick_params(axis='y', labelcolor='navy')
ax1.grid(True, linestyle='--', alpha=0.5)

# dark background for forecast area
ax1.axvspan(forecast_start, forecast['ds'].max(), facecolor='lightblue', alpha=0.1)


ax1.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import mpld3

# Your plotting code here...
fig = plt.figure(figsize=(14, 6))  # Set desired width and height

# Save as full-size HTML
mpld3.save_html(fig, 'forecast_diarrheal_deaths.html')

# %%
#increase size

import plotly.graph_objects as go
import datetime

# Create Plotly figure
plotly_fig = go.Figure()

# Mean forecast line
plotly_fig.add_trace(go.Scatter(
    x=forecast['ds'], y=forecast['yhat'],
    mode='lines', name='Forecasted Death Rate',
    line=dict(color='navy')
))

# Confidence interval (shaded area)
plotly_fig.add_trace(go.Scatter(
    x=forecast['ds'], y=forecast['yhat_upper'],
    mode='lines', line=dict(width=0), showlegend=False
))
plotly_fig.add_trace(go.Scatter(
    x=forecast['ds'], y=forecast['yhat_lower'],
    mode='lines', fill='tonexty',
    fillcolor='rgba(173,216,230,0.4)',
    line=dict(width=0), name='Confidence Interval'
))

# Historical data points
plotly_fig.add_trace(go.Scatter(
    x=model.history['ds'], y=model.history['y'],
    mode='markers', name='Observed Data',
    marker=dict(color='black', size=5)
))

# Forecast start date
forecast_start = model.history['ds'].max().to_pydatetime()

# Vertical line for forecast start
plotly_fig.add_shape(
    type="line",
    x0=forecast_start, x1=forecast_start,
    y0=0, y1=1, xref='x', yref='paper',
    line=dict(color="red", width=2, dash="dash")
)

# Forecast start annotation
plotly_fig.add_annotation(
    x=forecast_start, y=1.05,
    xref='x', yref='paper',
    text="Forecast Start",
    showarrow=False,
    font=dict(color="red")
)

plotly_fig.update_layout(
    title="Forecast: Global Death Rate from Diarrheal Diseases (per 100,000)",
    xaxis_title="Year",
    yaxis_title="Death Rate (per 100,000 people)",
    template="plotly_white",
    legend=dict(x=0.01, y=0.99),
    height=1500,

    # ensures the full data is visible on first load
    xaxis=dict(range=[forecast['ds'].min(), forecast['ds'].max()]),
    yaxis=dict(range=[
        min(forecast['yhat_lower'].min(), model.history['y'].min()),
        max(forecast['yhat_upper'].max(), model.history['y'].max())
    ])
)


# Save as HTML
plotly_fig.write_html("visual_charts_graphs/forecast_diarrheal_ddd.html")

# %%
import plotly.graph_objects as go

fig = go.Figure()

# Mean forecast line
fig.add_trace(go.Scatter(x=forecast['ds'], y=forecast['yhat'], mode='lines', name='Forecasted Death Rate', line=dict(color='navy')))

# Confidence interval
fig.add_trace(go.Scatter(x=forecast['ds'], y=forecast['yhat_upper'], mode='lines', line=dict(width=0), showlegend=False))
fig.add_trace(go.Scatter(x=forecast['ds'], y=forecast['yhat_lower'], mode='lines', fill='tonexty', fillcolor='rgba(173,216,230,0.4)', line=dict(width=0), name='Confidence Interval'))

# Historical data
fig.add_trace(go.Scatter(x=model.history['ds'], y=model.history['y'], mode='markers', name='Observed Data', marker=dict(color='black', size=5)))

import datetime

forecast_start = model.history['ds'].max().to_pydatetime()

# Add vertical line as shape
fig.add_shape(
    type="line",
    x0=forecast_start,
    x1=forecast_start,
    y0=0,
    y1=1,
    xref='x',
    yref='paper',
    line=dict(color="red", width=2, dash="dash"),
)

# Optional: Add annotation for label
fig.add_annotation(
    x=forecast_start,
    y=1.05,
    xref='x',
    yref='paper',
    text="Forecast Start",
    showarrow=False,
    font=dict(color="red"),
)




# Layout
fig.update_layout(
    title="Forecast: Global Death Rate from Diarrheal Diseases (per 100,000)",
    xaxis_title="Year",
    yaxis_title="Death Rate (per 100,000 people)",
    template="plotly_white",
    legend=dict(x=0.01, y=0.99),
    height=500
)

fig.write_html("forecast_plot.html")

# %%
import os

# Ensure directory exists
os.makedirs("visual_charts_graphs/images", exist_ok=True)

# Save as PNG
plt.savefig("visual_charts_graphs/images/forecast_diarrhea.png", dpi=300, bbox_inches='tight', facecolor='white')

# %%
import mpld3
mpld3.save_html(fig, "forecast_diarrheal_deaths.html")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 2
#       1 import mpld3
# ----> 2 mpld3.save_html(fig, "forecast_diarrheal_deaths.html")
#
# File /opt/miniconda3/envs/SP/lib/python3.11/site-packages/mpld3/_display.py:464, in save_html(fig, fileobj, **kwargs)
#     462 if not hasattr(fileobj, 'write'):
#     463     raise ValueError("fileobj should be a filename or a writable file")
# --> 464 fileobj.write(fig_to_html(fig, **kwargs))
#
# File /opt/miniconda3/envs/SP/lib/python3.11/site-packages/mpld3/_display.py:250, in fig_to_html(fig, d3_url, mpld3_url, no_extras, template_type, figid, use_http, include_libraries, **kwargs)
#     247     raise ValueError("figid must not contain spaces")
#     249 renderer = MPLD3Renderer()
# --> 250 Exporter(renderer, close_mpl=False, **kwargs).run(fig)
# ...

# %%
import os

os.makedirs("visual_charts_graphs/images", exist_ok=True)

# %%
plt.savefig("visual_charts_graphs/images/forecast_diarrhea.png", dpi=300, bbox_inches='tight', facecolor='white')

# %%
fig2 = model.plot_components(forecast)
plt.show()

# %%
from prophet.plot import plot_components_plotly
import plotly.io as pio

# Create Plotly version of components
fig2 = plot_components_plotly(model, forecast)

# Save to HTML separately
pio.write_html(fig2, file="components_plot.html", auto_open=False)

# %%
fig.write_html(
    "visual_charts_graphs/forecast_trend_component.html",
    include_plotlyjs='cdn',
    full_html=True,
    config={"responsive": True},
    default_width='100%',
    default_height=500  # or 600
)

# %%
fig.write_html(
    "visual_charts_graphs/forecast_seasonality_component.html",
    include_plotlyjs='cdn',
    full_html=True,
    config={"responsive": True},
    default_width='100%',
    default_height=500
)

# %%
import plotly.graph_objects as go
import pandas as pd

# --- Trend Plot ---
fig_trend = go.Figure()
fig_trend.add_trace(go.Scatter(
    x=forecast['ds'],
    y=forecast['trend'],
    mode='lines',
    name='Trend',
    line=dict(color='royalblue')
))
fig_trend.update_layout(
    title='Trend Component of Diarrheal Death Forecast',
    xaxis_title='Year',
    yaxis_title='Trend Value',
    template='plotly_white'
)
fig_trend.write_html("visual_charts_graphs/forecast_trend_component.html")

# %%
# --- Yearly Seasonality ---
fig_seasonality = go.Figure()
fig_seasonality.add_trace(go.Scatter(
    x=forecast['ds'],
    y=forecast['yearly'],
    mode='lines',
    name='Seasonality',
    line=dict(color='seagreen')
))
fig_seasonality.update_layout(
    title='Yearly Seasonality Component',
    xaxis_title='Time',
    yaxis_title='Seasonal Effect',
    template='plotly_white'
)
fig_seasonality.write_html("visual_charts_graphs/forecast_seasonality_component.html")
